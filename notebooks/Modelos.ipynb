# %%
# !pip install gensim==3.8.3

# %%
import pandas as pd
import gensim as gensim
import numpy as np
from numpy import dot
from numpy.linalg import norm
from gensim.models import Word2Vec
from gensim.models import FastText
from gensim.scripts import word2vec2tensor
from gensim.models.callbacks import CallbackAny2Vec
import re
from google.colab import drive
from gensim.models import KeyedVectors
from gensim.test.utils import datapath

# %%
drive.mount('/content/drive')
# %cd /content/drive/My Drive/TCCLG
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/TCCLG

# %% [markdown]
# ### Esse arquivo apenas carrega os modelos e mostra os coeficientes de similaridades para algumas palavras escolhidas e apresentadas no texto do TCC. É necessário rodar os outros 3 notebooks primeiro.

# %%
model_silabas_basico = KeyedVectors.load_word2vec_format('model_silabas_basico.model', binary=True)

# %%
model_silabas_contagem = KeyedVectors.load_word2vec_format('model_silabas_contagem.model', binary=True)

# %%
model_silabas_chunk = KeyedVectors.load_word2vec_format("model_silabas_chunk.model", binary=True)

# %%
model_silabas_contagem_chunk = KeyedVectors.load_word2vec_format("model_silabas_contagem_chunk.model", binary=True)

# %%
model_fonetica_basico = KeyedVectors.load_word2vec_format('model_fonetica_basico.model', binary=True)

# %%
model_fonetica_contagem = KeyedVectors.load_word2vec_format('model_fonetica_contagem.model', binary=True)

# %%
model_fonetica_chunk = KeyedVectors.load_word2vec_format("model_fonetica_chunk.model", binary=True)

# %%
model_fonetica_contagem_chunk = KeyedVectors.load_word2vec_format("model_fonetica_contagem_chunk.model", binary=True)

# %%
model_etiquetas_basico = KeyedVectors.load_word2vec_format('model_etiquetas_basico.model', binary=True)

# %%
model_etiquetas_contagem = KeyedVectors.load_word2vec_format('model_etiquetas_contagem.model', binary=True)

# %%
model_etiquetas_chunk = KeyedVectors.load_word2vec_format("model_etiquetas_chunk.model", binary=True)

# %%
model_etiquetas_contagem_chunk = KeyedVectors.load_word2vec_format("model_etiquetas_contagem_chunk.model", binary=True)

# %%
# print(model_silabas_basico.most_similar('aleatoriamente')[:5])
# print(model_silabas_contagem_chunk.most_similar('aleatoriamente')[:5])
# print(model_silabas_basico.most_similar('aleatoriedade')[:5])
# print(model_silabas_contagem_chunk.most_similar('aleatoriedade')[:5])
# print(model_silabas_basico.most_similar('academicamente')[:5])
# print(model_silabas_contagem_chunk.most_similar('academicamente')[:5])
# print(model_silabas_basico.most_similar('filologa')[:5])
# print(model_silabas_contagem_chunk.most_similar('filologa')[:5])

print(model_silabas_basico.most_similar('bebedouro')[:5])
print(model_silabas_contagem_chunk.most_similar('bebedouro')[:5])
print(model_fonetica_basico.most_similar('bebedouro')[:5])
print(model_fonetica_contagem_chunk.most_similar('bebedouro')[:5])
print(model_etiquetas_basico.most_similar('bebedouro')[:5])
print(model_etiquetas_contagem_chunk.most_similar('bebedouro')[:5])
print("")
print(model_silabas_basico.most_similar('cancun')[:5])
print(model_silabas_contagem_chunk.most_similar('cancun')[:5])
print(model_fonetica_basico.most_similar('cancun')[:5])
print(model_fonetica_contagem_chunk.most_similar('cancun')[:5])
print(model_etiquetas_basico.most_similar('cancun')[:5])
print(model_etiquetas_contagem_chunk.most_similar('cancun')[:5])
print("")
print(model_silabas_basico.most_similar('canto')[:5])
print(model_silabas_contagem_chunk.most_similar('canto')[:5])
print(model_fonetica_basico.most_similar('canto')[:5])
print(model_fonetica_contagem_chunk.most_similar('canto')[:5])
print(model_etiquetas_basico.most_similar('canto')[:5])
print(model_etiquetas_contagem_chunk.most_similar('canto')[:5])

#print(model_silabas_basico.most_similar('bebedor')[:5])
#print(model_silabas_contagem_chunk.most_similar('bebedor')[:5])
# Out:
# [('bebedouros', 0.9704554677009583), ('bebedeira', 0.9175080060958862), ('cabeça-dura', 0.9065192937850952), ('bebedeiras', 0.9062117338180542), ('cabeçudos', 0.9045641422271729)]
# [('bebedouros', 0.9780352115631104), ('bebedeiras', 0.8973835110664368), ('bebedeira', 0.8957095146179199), ('beberrao', 0.8902757167816162), ('duradouro', 0.8707091808319092)]
# [('bebedouros', 0.977584719657898), ('bebedeiras', 0.9367777109146118), ('bebedeira', 0.9273442625999451), ('belem', 0.9016820788383484), ('zombeteiro', 0.8999277353286743)]
# [('bebedouros', 0.9902833700180054), ('bebedeiras', 0.9203789234161377), ('bebedeira', 0.9171321392059326), ('beberrao', 0.8928313255310059), ('bebedor', 0.8902280330657959)]
# [('matadouro', 0.976898729801178), ('matadeiro', 0.974719762802124), ('motoqueiro', 0.9727163314819336), ('caldeira', 0.9710835814476013), ('barraqueiro', 0.9704741835594177)]
# ...

# %%
print(model_silabas_basico.most_similar('bebedouro')[:5])
print(model_fonetica_basico.most_similar('bebedouro')[:5])
print(model_etiquetas_basico.most_similar('bebedouro')[:5])
print("")
print(model_etiquetas_basico.most_similar('bebedouro')[:5])
print(model_etiquetas_contagem.most_similar('bebedouro')[:5])
print("")
print(model_etiquetas_basico.most_similar('bebedouro')[:5])
print(model_etiquetas_chunk.most_similar('bebedouro')[:5])
print("")
print(model_etiquetas_basico.most_similar('bebedouro')[:5])
print(model_etiquetas_contagem_chunk.most_similar('bebedouro')[:5])
print("")
print(model_silabas_contagem_chunk.most_similar('bebedouro')[:5])
print(model_fonetica_contagem_chunk.most_similar('bebedouro')[:5])
print(model_etiquetas_contagem_chunk.most_similar('bebedouro')[:5])
# Out:
# [('bebedouros', 0.9704554677009583), ('bebedeira', 0.9175080060958862), ('cabeça-dura', 0.9065192937850952), ('bebedeiras', 0.9062117338180542), ('cabeçudos', 0.9045641422271729)]
# [('bebedouros', 0.977584719657898), ('bebedeiras', 0.9367777109146118), ('bebedeira', 0.9273442625999451), ('belem', 0.9016820788383484), ('zombeteiro', 0.8999277353286743)]
# [('matadouro', 0.976898729801178), ('matadeiro', 0.974719762802124), ('motoqueiro', 0.9727163314819336), ('caldeira', 0.9710835814476013), ('barraqueiro', 0.9704741835594177)]
#
# [('matadouro', 0.976898729801178), ('matadeiro', 0.974719762802124), ('motoqueiro', 0.9727163314819336), ('caldeira', 0.9710835814476013), ('barraqueiro', 0.9704741835594177)]
# [('tabaqueira', 0.9588305950164795), ('debateu', 0.9547203779220581), ('desocupou', 0.953288733959198), ('bacabeira', 0.9508869647979736), ('catapultou', 0.9476488828659058)]
#
# ...

# %%
print(model_silabas_basico.most_similar('bebedor')[:5])
print(model_fonetica_basico.most_similar('bebedor')[:5])
print(model_etiquetas_basico.most_similar('bebedor')[:5])
print("")
print(model_etiquetas_basico.most_similar('bebedor')[:5])
print(model_etiquetas_contagem.most_similar('bebedor')[:5])
print("")
print(model_etiquetas_basico.most_similar('bebedor')[:5])
print(model_etiquetas_chunk.most_similar('bebedor')[:5])
print("")
print(model_etiquetas_basico.most_similar('bebedor')[:5])
print(model_etiquetas_contagem_chunk.most_similar('bebedor')[:5])
print("")
print(model_silabas_contagem_chunk.most_similar('bebedor')[:5])
print(model_fonetica_contagem_chunk.most_similar('bebedor')[:5])
print(model_etiquetas_contagem_chunk.most_similar('bebedor')[:5])
# Out:
# [('bebedores', 0.9553996324539185), ('sabedor', 0.9491344690322876), ('liberador', 0.9470173120498657), ('barbeador', 0.9403661489486694), ('beria', 0.9323768019676208)]
# [('bebedores', 0.9535619616508484), ('liberador', 0.9508180618286133), ('recebedor', 0.9461575746536255), ('barbeador', 0.942847490310669), ('barbeadores', 0.9343433976173401)]
# [('suportar', 0.9521743059158325), ('definidor', 0.9463016390800476), ('apaziguador', 0.9451307058334351), ('sinalizador', 0.943922758102417), ('classificador', 0.9438779354095459)]
#
# [('suportar', 0.9521743059158325), ('definidor', 0.9463016390800476), ('apaziguador', 0.9451307058334351), ('sinalizador', 0.943922758102417), ('classificador', 0.9438779354095459)]
# [('batucar', 0.9342607259750366), ('demodulador', 0.9325096011161804), ('coquetel', 0.9281891584396362), ('decoberta', 0.9275022745132446), ('dissipador', 0.9273409843444824)]
#
# ...

# %%
print(model_silabas_basico.most_similar('bebida')[:5])
print(model_fonetica_basico.most_similar('bebida')[:5])
print(model_etiquetas_basico.most_similar('bebida')[:5])
print("")
print(model_etiquetas_basico.most_similar('bebida')[:5])
print(model_etiquetas_contagem.most_similar('bebida')[:5])
print("")
print(model_etiquetas_basico.most_similar('bebida')[:5])
print(model_etiquetas_chunk.most_similar('bebida')[:5])
print("")
print(model_etiquetas_basico.most_similar('bebida')[:5])
print(model_etiquetas_contagem_chunk.most_similar('bebida')[:5])
print("")
print(model_silabas_contagem_chunk.most_similar('bebida')[:5])
print(model_fonetica_contagem_chunk.most_similar('bebida')[:5])
print(model_etiquetas_contagem_chunk.most_similar('bebida')[:5])
# Out:
# [('bebido', 0.9838595390319824), ('bebia', 0.983340859413147), ('bebidas', 0.9687331914901733), ('bebidos', 0.9677993059158325), ('bebi', 0.9668216705322266)]
# [('bebido', 0.9788423776626587), ('bebidos', 0.9776362180709839), ('bebidas', 0.9759680032730103), ('embebida', 0.9603312015533447), ('embebidos', 0.9588278532028198)]
# [('badeco', 0.9576464891433716), ('apagadas', 0.9562376737594604), ('inadequado', 0.9560134410858154), ('palatabilidade', 0.9550553560256958), ('isocorica', 0.9525132179260254)]
#
# [('badeco', 0.9576464891433716), ('apagadas', 0.9562376737594604), ('inadequado', 0.9560134410858154), ('palatabilidade', 0.9550553560256958), ('isocorica', 0.9525132179260254)]
# [('dedica', 0.9291318655014038), ('colodio', 0.9214848875999451), ('parado', 0.9194114208221436), ('calita', 0.9173940420150757), ('querubes', 0.9156380891799927)]
#
# ...

# %%
print(model_silabas_basico.most_similar('nadando')[:5])
print(model_fonetica_basico.most_similar('nadando')[:5])
print(model_etiquetas_basico.most_similar('nadando')[:5])
print("")
print(model_etiquetas_basico.most_similar('nadando')[:5])
print(model_etiquetas_contagem.most_similar('nadando')[:5])
print("")
print(model_etiquetas_basico.most_similar('nadando')[:5])
print(model_etiquetas_chunk.most_similar('nadando')[:5])
print("")
print(model_etiquetas_basico.most_similar('nadando')[:5])
print(model_etiquetas_contagem_chunk.most_similar('nadando')[:5])
print("")
print(model_silabas_contagem_chunk.most_similar('nadando')[:5])
print(model_fonetica_contagem_chunk.most_similar('nadando')[:5])
print(model_etiquetas_contagem_chunk.most_similar('nadando')[:5])
# Out:
# [('dando', 0.9265927076339722), ('invalidando', 0.9173684120178223), ('lidando', 0.9114346504211426), ('validando', 0.9113743901252747), ('apelidando', 0.9096890687942505)]
# [('arrecadando', 0.9353026747703552), ('nadar', 0.9262641072273254), ('andando', 0.9141401648521423), ('lidando', 0.9112201929092407), ('bradando', 0.910909116268158)]
# [('tando', 0.9854040741920471), ('pequim', 0.9851913452148438), ('abanto', 0.9833405017852783), ('tento', 0.9823148846626282), ('tombo', 0.9822493195533752)]
#
# [('tando', 0.9854040741920471), ('pequim', 0.9851913452148438), ('abanto', 0.9833405017852783), ('tento', 0.9823148846626282), ('tombo', 0.9822493195533752)]
# [('pango', 0.9761860370635986), ('pudenda', 0.9677894115447998), ('equante', 0.9676985144615173), ('tongo', 0.967130184173584), ('tonga', 0.9671065211296082)]
#
# [('tando', 0.9854040741920471), ('pequim', 0.9851913452148438), ('abanto', 0.9833405017852783), ('tento', 0.9823148846626282), ('tombo', 0.9822493195533752)]
# ...

# %%
print(model_silabas_basico.most_similar('lago')[:5])
print(model_fonetica_basico.most_similar('lago')[:5])
print(model_etiquetas_basico.most_similar('lago')[:5])
print("")
print(model_etiquetas_basico.most_similar('lago')[:5])
print(model_etiquetas_contagem.most_similar('lago')[:5])
print("")
print(model_etiquetas_basico.most_similar('lago')[:5])
print(model_etiquetas_chunk.most_similar('lago')[:5])
print("")
print(model_etiquetas_basico.most_similar('lago')[:5])
print(model_etiquetas_contagem_chunk.most_similar('lago')[:5])
print("")
print(model_silabas_contagem_chunk.most_similar('lago')[:5])
print(model_fonetica_contagem_chunk.most_similar('lago')[:5])
print(model_etiquetas_contagem_chunk.most_similar('lago')[:5])
# Out:
# [('gola', 0.9824570417404175), ('degolado', 0.9700422286987305), ('agolada', 0.9687426090240479), ('degolada', 0.9565696716308594), ('angolanas', 0.946208655834198)]
# [('lagos', 0.9561322331428528), ('ustilago', 0.9363766312599182), ('filago', 0.9362539052963257), ('alaga', 0.9291406869888306), ('laga', 0.9178017377853394)]
# [('agalega', 0.9422512054443359), ('assinara', 0.9282469749450684), ('ferreto', 0.9245951175689697), ('corados', 0.9227383732795715), ('paludo', 0.9212535619735718)]
#
# [('agalega', 0.9422512054443359), ('assinara', 0.9282469749450684), ('ferreto', 0.9245951175689697), ('corados', 0.9227383732795715), ('paludo', 0.9212535619735718)]
# [('evaporiticos', 0.9268397092819214), ('carriarico', 0.9218422174453735), ('requerida', 0.9205771684646606), ('punhalada', 0.9182435274124146), ('polido', 0.918033242225647)]
#
# ...
